# %%
import ebisim as es
# %load_ext line_profiler
import matplotlib.pyplot as plt
import scipy

# %%
problem = es.problems.ComplexEBISProblem("K", 50, 9000, 15)
# %lprun -f problem._rhs problem.solve(1, method="BDF")
# %lprun -f es.problems.scipy.integrate.RK45 problem.solve(1, method="RK45")
# Out:
# Timer unit: 2.77398e-07 s
#
# Total time: 5.22035 s
# File: H:\PhD\GitHubRepos\EBISSimulation\ebisim\problems.py
# Function: _rhs at line 344
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    344                                               def _rhs(self, t, y):
#    345                                                   """
#    346                                                   The right hand side of the ODE system for the complex EBIS problem
#    347                                                   """
#    348      4273      16817.0      3.9      0.1          del t # not currently needed
#    349                                                   ### Electron beam stuff
#    350      4273      23162.0      5.4      0.1          e_kin = self.e_kin
#    351      4273     727297.0    170.2      3.9          ve = plasma.electron_velocity(e_kin)
#    352      4273      15147.0      3.5      0.1          je = self._j / Q_E
#    353      4273      11741.0      2.7      0.1          Ne = je / ve
#    354      4273      47540.0     11.1      0.3          q = np.arange(self._element.z + 1)
#    355      4273      13626.0      3.2      0.1          A = self._element.a
#    356
#    357                                                   ### Split y vector into density and temperature
#    358      4273      21435.0      5.0      0.1          N = y[:self._element.z + 1]
#    359      4273      17285.0      4.0      0.1          kbT = y[self._element.z + 1:]
#    360                                                   # E = N * kbT # Not currently needed
#    361
#    362                                                   # precompute collision rates
#    363      4273    2504000.0    586.0     13.3          rij = plasma.ion_coll_rate_mat(N, N, kbT, kbT, A, A)
#    364      4273     179231.0     41.9      1.0          ri = np.sum(rij, axis=1)
#    365
#    366                                                   ### Particle density rates
#    367      4273     739814.0    173.1      3.9          R_ei = je * N * self._species.eixs.xs_vector(e_kin)
#    368      4273      48085.0     11.3      0.3          R_rr = je * N * self._species.rrxs.xs_vector(e_kin)
#    369      4273    1864810.0    436.4      9.9          R_dr = je * N * self._species.drxs.xs_vector(e_kin, self._fwhm)
#    370      4273    3996905.0    935.4     21.2          R_ax = plasma.escape_rate_axial(N, kbT, ri, self._Vtrap_ax)
#    371      4273    3493156.0    817.5     18.6          R_ra = plasma.escape_rate_radial(N, kbT, ri, A, self._Vtrap_ra, self._B_ax, self._r_dt)
#    372
#    373                                                   ### Energy density rates
#    374      4273      37391.0      8.8      0.2          S_ei = R_ei * kbT
#    375      4273      22515.0      5.3      0.1          S_rr = R_rr * kbT
#    376      4273      21376.0      5.0      0.1          S_dr = R_dr * kbT
#    377      4273      78283.0     18.3      0.4          S_ax = R_ax * (kbT + q * self._Vtrap_ax)
#    378      4273      16141.0      3.8      0.1          S_ra = R_ra * (kbT + q * (self._Vtrap_ra + self._r_dt * self._B_ax * \
#    379      4273     215556.0     50.4      1.1                                    np.sqrt(2 * Q_E * np.clip(kbT, 0, None) / (3 * A *M_P))))
#    380                                                   # Electron heating
#    381      4273    2225813.0    520.9     11.8          S_eh = plasma.electron_heating_vec(N, Ne, kbT, e_kin, A)
#    382                                                   # Energy transfer between charge states within same "species"
#    383      4273    1967679.0    460.5     10.5          S_tr = plasma.energy_transfer_vec(N, N, kbT, kbT, A, A, rij)
#    384
#    385                                                   ### Construct rhs for N (density)
#    386      4273      70015.0     16.4      0.4          R_tot = -(R_ei + R_rr + R_dr) - (R_ax + R_ra)
#    387      4273      71045.0     16.6      0.4          R_tot[1:] += R_ei[:-1]
#    388      4273      58448.0     13.7      0.3          R_tot[:-1] += R_rr[1:] + R_dr[1:]
#    389
#    390                                                   ### Construct rates for energy density flow
#    391      4273      66986.0     15.7      0.4          S_tot = -(S_ei + S_rr + S_dr) + S_eh + S_tr - (S_ax + S_ra)
#    392      4273      39857.0      9.3      0.2          S_tot[1:] += S_ei[:-1]
#    393      4273      51255.0     12.0      0.3          S_tot[:-1] += S_rr[1:] + S_dr[1:]
#    394
#    395                                                   ### Deduce temperature flow -> Integrating temperature instead of energy has proven more
#    396                                                   ### numerically stable
#    397      4273      54881.0     12.8      0.3          Q_tot = (S_tot - kbT * R_tot) / N
#    398      4273      53170.0     12.4      0.3          Q_tot[N <= MINIMAL_DENSITY] = 0 ### Freeze temperature if density is low (-> not meaningful)
#    399
#    400      4273      48562.0     11.4      0.3          return np.concatenate((R_tot, Q_tot))

# %%
# es.plotting.COLORMAP = plt.cm.brg
problem = es.problems.ComplexEBISProblem("K", 50, 9000, 15)
_=problem.solve(100, method="BDF")#, method="Radau")
# print(_)

# %%
fig =problem.plot_cs_evo()
# fig.gca().set_xlim(1e-6,1e2)
# fig.gca().set_yscale("log")
# fig.gca().set_ylim(1e-21, 1e16)
fig2 = problem.plot_energy_evo()
# fig2.gca().set_xlim(1e-6,1e2)
# fig2.gca().set_ylim(1e12, 1e23)
fig3 = problem.plot_temperature_evo()
# fig3.gca().set_xlim(1e-6,1e2)
# plt.gca().set_yscale("log")
# fig3.gca().set_ylim(1e-2, 1e3)
# fig3.gca().set_xlim(1e-9,5)
plt.show()

# %%
xs = es.xs.EIXS("K")

# %%
# %timeit xs.xs_vector(3000)
# Out:
# 125 ns ± 0.199 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
231966612637415.94/10**13
# Out:
# 23.196661263741593

# %%
plt.get_cmap("plasma")(2)
# Out:
# (0.075353000000000003, 0.027206000000000001, 0.53800700000000001, 1.0)

# %%
404578054.127 * (es.physconst.M_E/es.physconst.M_P)/39
# Out:
# 5649.746019443601
