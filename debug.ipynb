# %%
import ebisim as es
# %load_ext line_profiler
import matplotlib.pyplot as plt
import scipy

# %%
problem = es.problems.ComplexEBISProblem("K", 50, 9000, 15)
# %lprun -f problem._rhs problem.solve(1.2, method="BDF")
# %lprun -f es.problems.scipy.integrate.RK45 problem.solve(1, method="RK45")
# Out:
# Timer unit: 2.77398e-07 s
#
# Total time: 5.47012 s
# File: H:\PhD\GitHubRepos\EBISSimulation\ebisim\problems.py
# Function: _rhs at line 346
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    346                                               def _rhs(self, t, y):
#    347                                                   """
#    348                                                   The right hand side of the ODE system for the complex EBIS problem
#    349                                                   """
#    350                                                   # del t # not currently needed
#    351                                                   ### Electron beam stuff
#    352      3655      29767.0      8.1      0.2          e_kin = self.e_kin
#    353      3655     739215.0    202.2      3.7          ve = plasma.electron_velocity(e_kin)
#    354      3655      17519.0      4.8      0.1          je = self._j / Q_E
#    355      3655      14385.0      3.9      0.1          Ne = je / ve
#    356      3655      48175.0     13.2      0.2          q = np.arange(self._element.z + 1)
#    357      3655      16076.0      4.4      0.1          A = self._element.a
#    358
#    359                                                   ### Split y vector into density and temperature
#    360      3655      23339.0      6.4      0.1          N = y[:self._element.z + 1]
#    361      3655      19156.0      5.2      0.1          kbT = y[self._element.z + 1:]
#    362                                                   # E = N * kbT # Not currently needed
#    363
#    364                                                   # precompute collision rates
#    365      3655    2526429.0    691.2     12.8          rij = plasma.ion_coll_rate_mat(N, N, kbT, kbT, A, A)
#    366      3655     174565.0     47.8      0.9          ri = np.sum(rij, axis=1)
#    367
#    368                                                   ### Particle density rates
#    369      3655     741341.0    202.8      3.8          R_ei = je * N * self._species.eixs.xs_vector(e_kin)
#    370      3655      47748.0     13.1      0.2          R_rr = je * N * self._species.rrxs.xs_vector(e_kin)
#    371      3655    1964487.0    537.5     10.0          R_dr = je * N * self._species.drxs.xs_vector(e_kin, self._fwhm)
#    372      3655     108283.0     29.6      0.5          sigcx = 1.43e-16 * q**1.17 * self._bg_IP**-2.76
#    373      3655     163130.0     44.6      0.8          R_cx = N * self._bg_N0 * np.sqrt(8 * Q_E * np.clip(kbT, 0, None)/(PI * A * M_P)) * sigcx
#    374                                                   # if t > 1:
#    375                                                   #     print(R_ei)
#    376                                                   #     print(R_cx)
#    377      3655    4252916.0   1163.6     21.6          R_ax = plasma.escape_rate_axial(N, kbT, ri, self._Vtrap_ax)
#    378      3655    3573981.0    977.8     18.1          R_ra = plasma.escape_rate_radial(N, kbT, ri, A, self._Vtrap_ra, self._B_ax, self._r_dt)
#    379
#    380                                                   ### Energy density rates
#    381      3655      40576.0     11.1      0.2          S_ei = R_ei * kbT
#    382      3655      25339.0      6.9      0.1          S_rr = R_rr * kbT
#    383      3655      23902.0      6.5      0.1          S_dr = R_dr * kbT
#    384      3655      23577.0      6.5      0.1          S_cx = R_cx * kbT
#    385      3655      77010.0     21.1      0.4          S_ax = R_ax * (kbT + q * self._Vtrap_ax)
#    386      3655      18601.0      5.1      0.1          S_ra = R_ra * (kbT + q * (self._Vtrap_ra + self._r_dt * self._B_ax * \
#    387      3655     192672.0     52.7      1.0                                    np.sqrt(2 * Q_E * np.clip(kbT, 0, None) / (3 * A *M_P))))
#    388                                                   # Electron heating
#    389      3655    2329436.0    637.3     11.8          S_eh = plasma.electron_heating_vec(N, Ne, kbT, e_kin, A)
#    390                                                   # Energy transfer between charge states within same "species"
#    391      3655    1986253.0    543.4     10.1          S_tr = plasma.energy_transfer_vec(N, N, kbT, kbT, A, A, rij)
#    392
#    393                                                   ### Construct rhs for N (density)
#    394      3655      75500.0     20.7      0.4          R_tot = -(R_ei + R_rr + R_dr + R_cx) - (R_ax + R_ra)
#    395      3655      71171.0     19.5      0.4          R_tot[1:] += R_ei[:-1]
#    396      3655      67029.0     18.3      0.3          R_tot[:-1] += R_rr[1:] + R_dr[1:] + R_cx[1:]
#    397
#    398                                                   ### Construct rates for energy density flow
#    399      3655      70594.0     19.3      0.4          S_tot = -(S_ei + S_rr + S_dr + S_cx) + S_eh + S_tr - (S_ax + S_ra)
#    400      3655      40283.0     11.0      0.2          S_tot[1:] += S_ei[:-1]
#    401      3655      59445.0     16.3      0.3          S_tot[:-1] += S_rr[1:] + S_dr[1:] + S_cx[1:]
#    402
#    403                                                   ### Deduce temperature flow -> Integrating temperature instead of energy has proven more
#    404                                                   ### numerically stable
#    405      3655      55424.0     15.2      0.3          Q_tot = (S_tot - kbT * R_tot) / N
#    406      3655      52823.0     14.5      0.3          Q_tot[N <= MINIMAL_DENSITY] = 0 ### Freeze temperature if density is low (-> not meaningful)
#    407
#    408      3655      49293.0     13.5      0.2          return np.concatenate((R_tot, Q_tot))

# %%
# es.plotting.COLORMAP = plt.cm.brg
problem = es.problems.ComplexEBISProblem("K", 50, 2200, 15)
_=problem.solve(10, method="Radau")#, method="Radau")
# print(_)

# %%
fig =problem.plot_cs_evo()
# fig.gca().set_xlim(1e-6,1e2)
# fig.gca().set_yscale("log")
# fig.gca().set_ylim(1e-21, 1e16)
fig2 = problem.plot_energy_evo()
# fig2.gca().set_xlim(1e-6,1e2)
# fig2.gca().set_ylim(1e12, 1e23)
fig3 = problem.plot_temperature_evo()
# fig3.gca().set_xlim(1e-6,1e2)
# plt.gca().set_yscale("log")
# fig3.gca().set_ylim(1e-2, 1e3)
# fig3.gca().set_xlim(1e-9,5)
plt.show()

# %%
xs = es.xs.EIXS("K")

# %%
# %timeit xs.xs_vector(3000)
# Out:
# 125 ns ± 0.199 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
231966612637415.94/10**13
# Out:
# 23.196661263741593

# %%
plt.get_cmap("plasma")(2)
# Out:
# (0.075353000000000003, 0.027206000000000001, 0.53800700000000001, 1.0)

# %%
404578054.127 * (es.physconst.M_E/es.physconst.M_P)/39
# Out:
# 5649.746019443601

# %%
problem = es.problems.ComplexEBISProblem("K", 50, 2300, 15)
problem._bg_N0 =1e-6 / (0.025 * 1.6e-19)
_=problem.solve(10, method="BDF")#, method="Radau")
problem.plot_cs_evo()
problem = es.problems.ComplexEBISProblem("K", 50, 2300, 15)
problem._bg_N0 =0
_=problem.solve(10, method="BDF")#, method="Radau")
problem.plot_cs_evo()
plt.show()
