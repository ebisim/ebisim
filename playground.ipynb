# %%
from DR import *

# %%
import pandas as pd

# %%
pd.DataFrame(LotzCrossSections(10).cross_section_matrix(2000))
# Out:
#               0             1             2             3             4   \
# 0  -3.587940e-17  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1   3.587940e-17 -1.366869e-17  0.000000e+00  0.000000e+00  0.000000e+00
# 2   0.000000e+00  1.366869e-17 -6.752002e-18  0.000000e+00  0.000000e+00
# 3   0.000000e+00  0.000000e+00  6.752002e-18 -3.390901e-18  0.000000e+00
# 4   0.000000e+00  0.000000e+00  0.000000e+00  3.390901e-18 -1.907054e-18
# 5   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.907054e-18
# 6   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 8   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 9   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 10  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#               5             6             7             8             9    10
# ...

# %%
pd.DataFrame(RRCrossSections(19).cross_section_matrix(1000))
# Out:
#      0             1             2             3             4             5   \
# 0  -0.0  1.141969e-25  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1   0.0 -1.141969e-25  1.128752e-25  0.000000e+00  0.000000e+00  0.000000e+00
# 2   0.0  0.000000e+00 -1.128752e-25  1.127252e-25  0.000000e+00  0.000000e+00
# 3   0.0  0.000000e+00  0.000000e+00 -1.127252e-25  1.134561e-25  0.000000e+00
# 4   0.0  0.000000e+00  0.000000e+00  0.000000e+00 -1.134561e-25  1.148741e-25
# 5   0.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00 -1.148741e-25
# 6   0.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7   0.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 8   0.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 9   0.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 10  0.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
RRCrossSections(19).show_plot(xlim=[10, 1e5], ylim=[1e-22,1e-15])
LotzCrossSections(19).show_plot(xlim=[10, 1e5], ylim=[1e-22,1e-15])
